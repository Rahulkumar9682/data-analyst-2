# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([3,8,1,10,50])
plt.plot(ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints)
plt.plot(ypoints,'o',ms=50)
plt.show()

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='*',ms=20)
plt.show()

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='*',ms=20)
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.xlabel("Average pulse")
plt.ylabel("calorie burnage")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,120,115,120,125])
y=np.array([204,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker='*',ms=20)
plt.xlabel("Average pulse")
plt.ylabel("calorie burnage")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,120,115,120,125])
y=np.array([204,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker='*',ms=20)
plt.title("sports watch data")
plt.xlabel("Average pulse")
plt.ylabel("calorie burnage")
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","dates"]
plt.pie(y,labels=mylabels)
plt.show()

# %%
x=np.array(["a","b","c","0"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
